# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/default/venkat/human resources files/human resources files/HumanResources_Department.csv")

display(df)
